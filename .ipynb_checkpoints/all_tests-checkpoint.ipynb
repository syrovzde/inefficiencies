# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from arbitrage_main import arbitrage_profit

# %%
from sqlalchemy import create_engine
from sshtunnel import SSHTunnelForwarder
from arbitrage_main import arbitrage_profit
import matplotlib.pyplot as plt
from time import time
import numpy as np
ip = "147.32.83.171"
# Out:
# C:\Users\zdesi\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3f00abf7d899> in <module>
#       1 from sqlalchemy import create_engine
#       2 from sshtunnel import SSHTunnelForwarder
# ----> 3 from arbitrage_main import arbitrage_profit
#       4 import matplotlib.pyplot as plt
#       5 from time import time
#
# ModuleNotFoundError: No module named 'arbitrage_main'

# %%
ssh_tunnel = SSHTunnelForwarder(
    ip,
        ssh_username='syrovzde',
        ssh_private_key='C:\\Users\\zdesi\\.ssh\\syrovzde_rsa',
        remote_bind_address=('localhost', 5432)
    )
ssh_tunnel.start()
engine = create_engine("postgresql://{user}@{host}:{port}/{db}".format(
        host='localhost',
        port=ssh_tunnel.local_bind_port,
        user='syrovzde',
        db='asianodds'
    ))
result_engine = create_engine("postgresql://{user}@{host}:{port}/{db}".format(
        host='localhost',
        port=ssh_tunnel.local_bind_port,
        user='syrovzde',
        db='betexplorer'
    ))
match_ids=['1562868529', '1563026767', '1563108486', '1563032872', '1124895', '1125355', '1125355', '1125355', '1125355', '1125355', '1125355', '1069731784', '-818990875', '-818990875', '-818990875', '-818990875', '1563196446', '1563173599', '1562944376', '1563026806', '1563272518', '1563272518', '1563076444', '1563076444', '1563076041', '1563075993', '1563076275', '1563076246', '1563137534', '1563137534', '1563137534', '1563137534', '1563137534', '1563137534', '1563137534', '1563137534', '1563137534', '1563278866', '1563278866', '1563290671', '1563344125', '1563327032', '1563327032', '1563330733', '1563278880', '1563278880', '1563278909', '1563316090', '1563316090', '1563347359', '1563347359', '1563309882', '1563309882', '1563309882', '1563278997', '1563278997', '1563415916', '1563212686', '1563279346', '1563447847', '1563170318', '1563459710', '1563479791', '1563287438', '1563287438', '1563298350', '1563484566', '1563330633', '1563330225', '1563330402', '1563330204', '1563330204', '1563330435', '1563330392', '1563330392', '1563330303', '1563330303', '1563330303', '1563567614', '1563567614', '1563330411', '1563330411', '1563582455', '1563548691', '1563548349', '1563548696', '1563567088', '1563567088', '1563567088', '1563567088', '1563567088', '1563567088', '1563567088', '1563567088', '1563576622', '1563611391', '1563611391', '1563610244', '1563631135', '1563610241', '1563631133', '1563610237', '1563436869', '1563673298', '1563673298', '1563673296', '1563700816', '1563714589', '1563781645', '1564030349', '1563789328', '1563972354', '1563946046', '1563941912', '1563861593', '1563960777', '1563861358', '1563821891', '1564011560', '1564012012', '1564012012', '1564012012', '1564012012', '1563861184', '1563861055', '1563861055', '1563994527', '1564034875', '1564083301', '1563934490', '1564039918', '1564133487', '1564133487']

print("completed")
# Out:
# completed

# %%
profits_basic, betting_vectors_basic, matchids_profit_basic=arbitrage_profit(p=1,max_bet=1000,min_bet=0, engine=engine, res_engine=result_engine, weighted=False, uniform_weights = False,match_ids=match_ids)
# Out:
# 1562868529
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# ...

# %%
profits_uniform, betting_vectors_uniform, matchids_profit_uniform=arbitrage_profit(p=1,max_bet=1000, min_bet=0, engine=engine, res_engine=result_engine, weighted = True, uniform_weights = True,match_ids=match_ids)
# Out:
# 1562868529
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# ...

# %%
profits_lambda, betting_vectors_lambda, matchids_profit_lambda=arbitrage_profit(p=1,max_bet=1000, min_bet=0, engine=engine, res_engine=result_engine, weighted = True, lambda_weighted = True,match_ids=match_ids)

# %%
print(sum(profits_lambda)/len(profits_lambda))
print(sum(profits_uniform)/len(profits_uniform))
print(sum(profits_basic)/len(profits_basic))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2ef18bbe1500> in <module>
# ----> 1 print(sum(profits_lambda)/len(profits_lambda))
#       2 print(sum(profits_uniform)/len(profits_uniform))
#       3 print(sum(profits_basic)/len(profits_basic))
#
# NameError: name 'profits_lambda' is not defined

# %%
plt.boxplot(profits_lambda,labels='lambda')
plt.title("Profits from the bets classical variant")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ac2eb87c0d2> in <module>
# ----> 1 plt.boxplot(profits_lambda,labels='lambda')
#       2 plt.title("Profits from the bets classical variant")
#       3 plt.show()
#
# NameError: name 'plt' is not defined
